# %%
import pandas as pd

# Load cleaned merged dataset
df = pd.read_csv("../data/merged/cleaned_merged_data.csv")

# Display dataset shape and first few rows
print("Cleaned Merged Dataset Shape:", df.shape)
print(df.dtypes)
df.head()
# Out:
# Cleaned Merged Dataset Shape: (26759, 24)
# resultId               int64
# raceId                 int64
# driverId               int64
# constructorId          int64
# number               float64
# grid                   int64
# position             float64
# positionText          object
# positionOrder          int64
# points               float64
# laps                   int64
# time                  object
# milliseconds         float64
# fastestLap           float64
# rank                 float64
# fastestLapTime        object
# fastestLapSpeed      float64
# statusId               int64
# nationality            int64
# year                   int64
# circuitId              int64
# constructorRef         int64
# driver_experience    float64
# avg_team_points      float64
# dtype: object
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  ...  rank fastestLapTime  \
# 0            1              1    10.0  ...   2.0       1:27.452
# 1            2              2     8.0  ...   3.0       1:27.739
# 2            3              3     6.0  ...   5.0       1:28.090
# 3            4              4     5.0  ...   7.0       1:28.603
# 4            5              5     4.0  ...   1.0       1:27.418
#
#    fastestLapSpeed  statusId  nationality  year  circuitId  constructorRef  \
# 0          218.300         1            9  2008          1             131
# 1          217.586         1           20  2008          1              18
# 2          216.719         1           20  2008          1             208
# 3          215.464         1           37  2008          1             166
# 4          218.385         1           18  2008          1             131
#
#    driver_experience  avg_team_points
# 0               18.0        72.732508
# 1               18.0        41.885714
# 2               18.0        37.981914
# 3               18.0        42.285714
# 4               18.0        72.732508
#
# [5 rows x 24 columns]
